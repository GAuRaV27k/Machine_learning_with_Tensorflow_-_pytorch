# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")

# %%
sns.scatterplot(
    data= df,
    x = 'total_bill',
    y= 'tip',
    hue='sex',

    size= 'tip',
    style='smoker',
    # palette='Set2',
    # markers={'Yes': 's', 'No': 'o'}
)
plt.grid(True)
