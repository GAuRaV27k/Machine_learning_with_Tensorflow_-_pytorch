# %%
import torch
import torch.nn as nn

# %%
torch.manual_seed(42)
neuron = nn.Linear(
    in_features=2 ,
    out_features=1
)

# %%
import numpy as np 
import pandas as pd 
from sklearn.datasets import load_iris
df = load_iris(as_frame=True)

# %%
df.frame.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X = df.data[['petal length (cm)', 'petal width (cm)']].values
y = (df.target == 0)

# %%
X_new = [[2.0, 0.5], [3.0, 1.0]]
X_new_tensor = torch.tensor(X_new, dtype=torch.float32)

with torch.no_grad():
	y_pred = neuron(X_new_tensor)

y_pred
# Out:
# tensor([[1.2090],
#         [2.0431]])
