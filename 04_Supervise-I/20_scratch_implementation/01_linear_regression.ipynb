# %%
import numpy as np

# %% [markdown]
# linear Regression

# %%
# create the constructor 
class Linear_regression():
    def __init__(self, learning_rate=0.01, n_iter=1000):
        self.bias = None 
        self.weight = None 
        self.lr = learning_rate
        self.n_iter = n_iter
    
    def fit(self,X,y): # X_train and y_train]
        m,n = X.shape # number of sample and feature 

        # STEP -01 - INITIATIZSE THE PARAMETER 
        self.bias = 0
        self.weight = np.zeros(n)

        # Gradient Descent
        for _ in range(self.n_iter):
            # STEP - 02 - CALCUTE Y_PRED
            y_pred = self.bias + np.dot(X,self.weight)

            # STEP - 03 CALCULATE GRADIENT 
            db = (1/m) * np.sum(y_pred - y)
            dw = (1/m) * np.dot(X.T, (y_pred - y))
            
            # step 4 - UPDATE PARAMETERS

            self.bias -= self.lr * db 
            self.weight -= self.lr * dw 

    def predict(self,X):
        y_pred = self.bias + np.dot(X,self.weight)
        return y_pred

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])


model = Linear_regression()
model.fit(X,y)

y_pred = model.predict(X)

print(y_pred)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]
